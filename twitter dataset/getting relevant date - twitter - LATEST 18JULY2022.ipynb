# %% [markdown]
# # Getting relevant date

# %%
new_df_noninfluencers['Date'] = new_df_noninfluencers['Date'].astype('datetime64[ns]')
# Out:
# C:\Users\othmana\.conda\envs\testing\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df_noninfluencers_fromjan = new_df_noninfluencers.loc[new_df_noninfluencers['Date'] < "2022-01-01", :]

# %%
new_df_noninfluencers_fromjan.tail()
# Out:
#         Unnamed: 0        ID keywords       Date  tweet_timestamp  \
# 434598      436933  436934.0    covid 2021-12-31     1.640993e+09
# 434599      436934  436935.0    covid 2021-12-31     1.640993e+09
# 434600      436935  436936.0    covid 2021-12-31     1.640993e+09
# 434601      436936  436937.0    covid 2021-12-31     1.640994e+09
# 434602      436937  436938.0    covid 2021-12-31     1.640995e+09
#
#                                                                                                                                                                                                                                                      Tweet  \
# 434598  Ken36143959 Mellycat6 dalebloomfield3 Yes ivermectin has been debunked as a treatment for covid19 It showed some promise in vitro early on but the dosage being used to neutralize the virus was too high for the results to be replicated in vivo
# ...

# %%
len(new_df_noninfluencers_fromjan)
# Out:
# 199882

# %%
new_df_noninfluencers_fromjan.to_csv('twitter_data_janonwards_FINAL.csv')

# %%
new_df_noninfluencers_fromjuly = new_df_noninfluencers_fromjan.loc[new_df_noninfluencers_fromjan['Date'] > "2020-06-30", :]

# %%
new_df_noninfluencers_fromjuly.head()
# Out:
#         Unnamed: 0        ID keywords       Date  tweet_timestamp  \
# 136027      136978  136979.0    covid 2020-07-01     1.593562e+09
# 136028      136979  136980.0    covid 2020-07-01     1.593562e+09
# 136029      136980  136981.0    covid 2020-07-01     1.593563e+09
# 136030      136981  136982.0    covid 2020-07-01     1.593563e+09
# 136032      136983  136984.0    covid 2020-07-01     1.593563e+09
#
#                                                                                                                                          Tweet  \
# 136027    How Covid19 Is Changing Southeast Asia’s Consumers  For consumer goods companies understanding changes in consum… httpstco7ti8GtGQ86
# 136028    Covid19 reinforced why I do the role that I do in terms of leading from a position of support empathy and love o… httpstcoXwj9ZuMGnZ
# 136029  IlhanMN Government should come up with strategies and financial aid packages to mitigate the impact of Covid 19 Pandemic on the People
# ...

# %%
len(new_df_noninfluencers_fromjuly)
# Out:
# 140598

# %%
new_df_noninfluencers_fromjan.to_csv('twitter_data_julyonwards_FINAL.csv')
