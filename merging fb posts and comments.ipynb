# %%
import pandas as pd

#fb_covid_post_raj = pd.read_csv('facebook-posts-i_rajkeywords.csv')
#fb_covid_post_mine = pd.read_csv('facebook-posts-i_mykeywords.csv')

# %%
#fb_covid_post_raj.columns

# %%
#joined_dataset = pd.concat([fb_covid_post_raj,fb_covid_post_mine])

# %%
#joined_dataset.drop_duplicates(subset=['post_id'], keep = 'first', inplace=True)

# %%
#joined_dataset.to_csv('facebook_posts_covidkeywords.csv')

# %%
fb_covid_posts= pd.read_csv('facebook_posts_covidkeywords.csv')
fb_covid_comments=pd.read_csv('fb_covid_mw_cleaned_v4_latest_25AUG.csv')

# %%
#fb_covid_comments.columns

# %%
#fb_covid_comments.head()

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

mergedStuff = pd.merge(fb_covid_posts,fb_covid_comments, on=['post_id'], how='inner')
mergedStuff.head()
# Out:
#    Unnamed: 0_x  article_id    page_id_x                        post_id  \
# 0             0           0  93889432933  93889432933_10157498725827934
# 1             0           0  93889432933  93889432933_10157498725827934
# 2             0           0  93889432933  93889432933_10157498725827934
# 3             0           0  93889432933  93889432933_10157498725827934
# 4             0           0  93889432933  93889432933_10157498725827934
#
#                                         post_message  \
# 0  The Government is also actively recruiting fre...
# 1  The Government is also actively recruiting fre...
# 2  The Government is also actively recruiting fre...
# 3  The Government is also actively recruiting fre...
# 4  The Government is also actively recruiting fre...
#
#                                         post_caption  \
# 0  COVID-19: Singapore to spend S$3.5 billion on ...
# 1  COVID-19: Singapore to spend S$3.5 billion on ...
# ...

# %%
mergedStuff.columns
# Out:
# Index(['Unnamed: 0_x', 'article_id', 'page_id_x', 'post_id', 'post_message',
#        'post_caption', 'post_description', 'post_timestamp',
#        'post_creation_time', 'post_link', 'status_type', 'post_type',
#        'like_count', 'comment_count', 'share_count', 'Unnamed: 0_y',
#        'Unnamed: 0.1', 'page_id_y', 'user_id', 'username', 'entry_id',
#        'entry_text', 'entry_timestamp', 'creation_time', 'anger_score',
#        'fear_score', 'joy_score', 'sadness_score', 'valence', 'emotion_score',
#        'sentiment_score', 'emotion_category', 'sentiment_category',
#        'is_2019-ncov', 'is_unemploy', 'is_wfh', 'is_foreign worker',
#        'page_name', 'len_count', ' entry_text_cleaned', 'utc_time', 'sg_time',
#        'date', 'processed_content', 'lemmatized_content'],
#       dtype='object')

# %%
mergedStuff.drop(['Unnamed: 0_x', 'Unnamed: 0_y',
       'Unnamed: 0.1', 'page_id_y'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\.conda\envs\testing\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\.conda\envs\testing\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     403                         if cls is not object \
#     404                                 and callable(cls.__dict__.get('__repr__')):
# --> 405                             return _repr_pprint(obj, self, cycle)
#     406
#     407             return _default_pprint(obj, self, cycle)
#
# ~\.conda\envs\testing\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...

# %%
mergedStuff.to_csv('fb_covid_MW_postsANDcomments_26AUG.csv')

# %%
extracovid_posts = pd.read_csv('facebook-posts-i_extrakeywords.csv')

# %%
extracovid_posts.head()
