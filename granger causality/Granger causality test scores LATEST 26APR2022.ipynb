# %%
#https://www.machinelearningplus.com/time-series/vector-autoregression-examples-python/
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Import Statsmodels
from statsmodels.tsa.stattools import grangercausalitytests
# Out:
# C:\Users\othmana\.conda\envs\testing\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_excel('full_dataset_groupbydate_normalized - 14JAN FINAL.xlsx', index_col='date')

# %%
df.head()
# Out:
#             SN  new_cases  cumulative_cases  new_deaths  cumulative_deaths  \
# date
# 2020-01-01   1          0                 0           0                  0
# 2020-02-01   2          0                 0           0                  0
# 2020-03-01   3          0                 0           0                  0
# 2020-04-01   4          0                 0           0                  0
# 2020-05-01   5          0                 0           0                  0
#
#             announcement_count  fb_count  fb_fear_count  fb_fear_percentage  \
# date
# 2020-01-01                   0         0              0                 0.0
# 2020-02-01                   1         0              0                 0.0
# 2020-03-01                   0         0              0                 0.0
# 2020-04-01                   1         0              0                 0.0
# 2020-05-01                   1         0              0                 0.0
#
#             fb_fear_intensity  ...  \
# date                           ...
# 2020-01-01                0.0  ...
# 2020-02-01                0.0  ...
# 2020-03-01                0.0  ...
# 2020-04-01                0.0  ...
# 2020-05-01                0.0  ...
#
#             normalized_mindline_source_youtube_dtt_total_users  \
# date
# 2020-01-01                                                0.0
# 2020-02-01                                                0.0
# 2020-03-01                                                0.0
# 2020-04-01                                                0.0
# 2020-05-01                                                0.0
#
#             normalized_mindline_source_youtube_dtt_new_users  \
# date
# 2020-01-01                                               0.0
# 2020-02-01                                               0.0
# 2020-03-01                                               0.0
# 2020-04-01                                               0.0
# 2020-05-01                                               0.0
#
#             normalized_mindline_source_youtube_well_total_users  \
# date
# 2020-01-01                                                0.0
# 2020-02-01                                                0.0
# 2020-03-01                                                0.0
# 2020-04-01                                                0.0
# 2020-05-01                                                0.0
#
#             normalized_mindline_source_youtube_well_new_users  \
# date
# 2020-01-01                                                0.0
# 2020-02-01                                                0.0
# 2020-03-01                                                0.0
# 2020-04-01                                                0.0
# 2020-05-01                                                0.0
#
#             normalized_mindline_source_youtube_mild_total_users  \
# date
# 2020-01-01                                                0.0
# 2020-02-01                                                0.0
# 2020-03-01                                                0.0
# 2020-04-01                                                0.0
# 2020-05-01                                                0.0
#
#             normalized_mindline_source_youtube_mild_new_users  \
# date
# 2020-01-01                                                0.0
# 2020-02-01                                                0.0
# 2020-03-01                                                0.0
# 2020-04-01                                                0.0
# 2020-05-01                                                0.0
#
#             normalized_mindline_source_youtube_moderate_total_users  \
# date
# 2020-01-01                                                0.0
# 2020-02-01                                                0.0
# 2020-03-01                                                0.0
# 2020-04-01                                                0.0
# 2020-05-01                                                0.0
#
#             normalized_mindline_source_youtube_moderate_new_users  \
# date
# 2020-01-01                                                0.0
# 2020-02-01                                                0.0
# 2020-03-01                                                0.0
# 2020-04-01                                                0.0
# 2020-05-01                                                0.0
#
#             normalized_mindline_source_youtube_crisis_total_users  \
# date
# 2020-01-01                                                0.0
# 2020-02-01                                                0.0
# 2020-03-01                                                0.0
# 2020-04-01                                                0.0
# 2020-05-01                                                0.0
#
#             normalized_mindline_source_youtube_crisis_new_users
# date
# 2020-01-01                                                0.0
# 2020-02-01                                                0.0
# 2020-03-01                                                0.0
# 2020-04-01                                                0.0
# 2020-05-01                                                0.0
#
# [5 rows x 255 columns]

# %%
df.columns
# Out:
# Index(['SN', 'new_cases', 'cumulative_cases', 'new_deaths',
#        'cumulative_deaths', 'announcement_count', 'fb_count', 'fb_fear_count',
#        'fb_fear_percentage', 'fb_fear_intensity',
#        ...
#        'normalized_mindline_source_youtube_dtt_total_users',
#        'normalized_mindline_source_youtube_dtt_new_users',
#        'normalized_mindline_source_youtube_well_total_users',
#        'normalized_mindline_source_youtube_well_new_users',
#        'normalized_mindline_source_youtube_mild_total_users',
#        'normalized_mindline_source_youtube_mild_new_users',
#        'normalized_mindline_source_youtube_moderate_total_users',
#        'normalized_mindline_source_youtube_moderate_new_users',
#        'normalized_mindline_source_youtube_crisis_total_users',
#        'normalized_mindline_source_youtube_crisis_new_users'],
#       dtype='object', length=255)

# %%
###video ref https://www.youtube.com/watch?v=4TkNZviNJC0

#put the column that you think is granger caused (variable Y) first
ts_df = df[['normalized_mindline_source_fb_crisis_total_users','normalized_tweet_anger_count']]

# %%
#ts_df.dropna(inplace=True)

# %%
results = grangercausalitytests(ts_df,5)
#5 refers to the number of lags
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.0110  , p=0.0255  , df_denom=727, df_num=1
# ssr based chi2 test:   chi2=5.0317  , p=0.0249  , df=1
# likelihood ratio test: chi2=5.0144  , p=0.0251  , df=1
# parameter F test:         F=5.0110  , p=0.0255  , df_denom=727, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=4.4448  , p=0.0121  , df_denom=724, df_num=2
# ssr based chi2 test:   chi2=8.9509  , p=0.0114  , df=2
# likelihood ratio test: chi2=8.8964  , p=0.0117  , df=2
# parameter F test:         F=4.4448  , p=0.0121  , df_denom=724, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.0535  , p=0.0072  , df_denom=721, df_num=3
# ssr based chi2 test:   chi2=12.2785 , p=0.0065  , df=3
# likelihood ratio test: chi2=12.1761 , p=0.0068  , df=3
# parameter F test:         F=4.0535  , p=0.0072  , df_denom=721, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=2.9695  , p=0.0189  , df_denom=718, df_num=4
# ssr based chi2 test:   chi2=12.0271 , p=0.0172  , df=4
# likelihood ratio test: chi2=11.9287 , p=0.0179  , df=4
# parameter F test:         F=2.9695  , p=0.0189  , df_denom=718, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.2463  , p=0.0066  , df_denom=715, df_num=5
# ssr based chi2 test:   chi2=16.4814 , p=0.0056  , df=5
# likelihood ratio test: chi2=16.2972 , p=0.0060  , df=5
# parameter F test:         F=3.2463  , p=0.0066  , df_denom=715, df_num=5
