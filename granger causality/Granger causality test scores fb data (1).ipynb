# %%
#https://www.machinelearningplus.com/time-series/vector-autoregression-examples-python/
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Import Statsmodels
from statsmodels.tsa.stattools import grangercausalitytests

# %%
df = pd.read_excel('data - aggregated daily columns - NORMALIZED - redo fb data - 07DEC2022.xlsx', index_col='date')

# %%
df.head()
# Out:
#             SN  new_cases  cumulative_cases  new_deaths  cumulative_deaths  \
# date
# 2020-07-01   1        246             43907           0                 26
# 2020-07-02   2        215             44122           0                 26
# 2020-07-03   3        188             44310           0                 26
# 2020-07-04   4        169             44479           0                 26
# 2020-07-05   5        185             44664           0                 26
#
#             announcement_count  fb_count  fb_fear_count  fb_fear_percentage  \
# date
# 2020-07-01                   4      7318           1425           19.472533
# 2020-07-02                   4      7014           1591           22.683205
# 2020-07-03                   5      6420           1707           26.588785
# 2020-07-04                   3     10502           2161           20.577033
# 2020-07-05                   4     19963           4021           20.142263
#
# ...

# %%
df.columns
# Out:
# Index(['SN', 'new_cases', 'cumulative_cases', 'new_deaths',
#        'cumulative_deaths', 'announcement_count', 'fb_count', 'fb_fear_count',
#        'fb_fear_percentage', 'fb_fear_intensity',
#        ...
#        'normalized_moh_religion', 'normalized_moh_travelborder',
#        'normalized_moh_vaccination', 'normalized_moh_heightenedalert',
#        'normalized_moh_travel', 'normalized_moh_reopening',
#        'normalized_moh_safemanagementmeasures', 'normalized_moh_education',
#        'normalized_moh_ministertranscript', 'normalized_imh_visits'],
#       dtype='object', length=133)

# %%
###video ref https://www.youtube.com/watch?v=4TkNZviNJC0

#put the column that you think is granger caused (variable Y) first
ts_df = df[['normalized_mindline_well_new_users','normalized_new_deaths']]

# %%
#ts_df.dropna(inplace=True)

# %%
results = grangercausalitytests(ts_df,5)


#5 refers to the number of lags
# Out:
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2021  , p=0.2734  , df_denom=545, df_num=1
# ssr based chi2 test:   chi2=1.2087  , p=0.2716  , df=1
# likelihood ratio test: chi2=1.2074  , p=0.2719  , df=1
# parameter F test:         F=1.2021  , p=0.2734  , df_denom=545, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.2531  , p=0.0394  , df_denom=542, df_num=2
# ssr based chi2 test:   chi2=6.5663  , p=0.0375  , df=2
# likelihood ratio test: chi2=6.5272  , p=0.0383  , df=2
# parameter F test:         F=3.2531  , p=0.0394  , df_denom=542, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.0824  , p=0.1015  , df_denom=539, df_num=3
# ssr based chi2 test:   chi2=6.3282  , p=0.0967  , df=3
# likelihood ratio test: chi2=6.2918  , p=0.0982  , df=3
# parameter F test:         F=2.0824  , p=0.1015  , df_denom=539, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ...
