# %%
import pandas as pd

df1= pd.read_csv('SG_twitter_trollremoved_V3_26AUG.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    ID keywords      tweet_ID      tweet_timestamp  \
# 0           2           2.0   3.0    wuhan  1.224740e+18  2020-02-05 01:00:37
# 1          12          12.0  13.0    wuhan  1.224719e+18  2020-02-04 23:37:39
# 2          22          22.0  23.0    wuhan  1.224709e+18  2020-02-04 23:00:34
# 3          28          28.0  29.0    wuhan  1.224703e+18  2020-02-04 22:35:06
# 4          49          49.0  50.0    wuhan  1.224690e+18  2020-02-04 21:43:01
#
#                                                Tweet  retweet_count  \
# 0  The Wuhan Coronavirus Poses Three Tests for Gl...            0.0
# 1  #HIV drugs used to treat small number of #coro...            0.0
# 2  What crisis managers need to do when dealing w...            0.0
# 3  #Singapore #WuhanVirus #Coronavirus #2019nCoV ...            0.0
# 4  The number of people infected with #coronaviru...            0.0
#
#    favourite_count                                   HashTags  ...    joy  \
# ...

# %%
df1['influencer_score']=df1['user_followers']/df1['user_friends']

# %%
df1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    ID keywords      tweet_ID      tweet_timestamp  \
# 0           2           2.0   3.0    wuhan  1.224740e+18  2020-02-05 01:00:37
# 1          12          12.0  13.0    wuhan  1.224719e+18  2020-02-04 23:37:39
# 2          22          22.0  23.0    wuhan  1.224709e+18  2020-02-04 23:00:34
# 3          28          28.0  29.0    wuhan  1.224703e+18  2020-02-04 22:35:06
# 4          49          49.0  50.0    wuhan  1.224690e+18  2020-02-04 21:43:01
#
#                                                Tweet  retweet_count  \
# 0  The Wuhan Coronavirus Poses Three Tests for Gl...            0.0
# 1  #HIV drugs used to treat small number of #coro...            0.0
# 2  What crisis managers need to do when dealing w...            0.0
# 3  #Singapore #WuhanVirus #Coronavirus #2019nCoV ...            0.0
# 4  The number of people infected with #coronaviru...            0.0
#
#    favourite_count                                   HashTags  ...  valence  \
# ...

# %%
def det_info_status(row):
    if float((row['influencer_score'])) > 1:
        val = "info-disseminators"
    else:
        val = "info-seeking"
    return val

# %%
def det_info_status(row):
    if float((row['influencer_score'])) > 1:
        val = 0
    else:
        val = 1
    return val

# %%
df1["info_status"] = df1.apply(det_info_status, axis=1)

# %%
df1.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    ID keywords      tweet_ID      tweet_timestamp  \
# 0           2           2.0   3.0    wuhan  1.224740e+18  2020-02-05 01:00:37
# 1          12          12.0  13.0    wuhan  1.224719e+18  2020-02-04 23:37:39
# 2          22          22.0  23.0    wuhan  1.224709e+18  2020-02-04 23:00:34
# 3          28          28.0  29.0    wuhan  1.224703e+18  2020-02-04 22:35:06
# 4          49          49.0  50.0    wuhan  1.224690e+18  2020-02-04 21:43:01
#
#                                                Tweet  retweet_count  \
# 0  The Wuhan Coronavirus Poses Three Tests for Gl...            0.0
# 1  #HIV drugs used to treat small number of #coro...            0.0
# 2  What crisis managers need to do when dealing w...            0.0
# 3  #Singapore #WuhanVirus #Coronavirus #2019nCoV ...            0.0
# 4  The number of people infected with #coronaviru...            0.0
#
#    favourite_count                                   HashTags  ...  \
# ...
